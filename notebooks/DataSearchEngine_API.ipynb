# %% [markdown]
# ---

# %% [markdown]
# **FastAPI**

# %%
# !pip install FastAPI -q
# !pip install uvicorn -q
# !pip install fastapi nest-asyncio pyngrok uvicorn -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.0/57.0 kB 1.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.9/66.9 kB 3.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 3.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 5.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 681.2/681.2 kB 10.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for pyngrok (setup.py) ... done

# %%
from fastapi import FastAPI
import nest_asyncio
from pyngrok import ngrok
import uvicorn

# %%
from pydantic import BaseModel

# %%
# !ngrok config add-authtoken 2PdKi1m8fTESfuaP65fqbglxmmx_5qJmCoMgiy7q3akdJaxBm
# Out:
# Authtoken saved to configuration file: /root/.ngrok2/ngrok.yml

# %%
class Company_Request(BaseModel):
    company_name: str
    company_country: str
    company_URL: str | None = None

# %%
class Company_Response(BaseModel):
    products_services: list | None = None
    keywords: list | None = None
    classification: list | None = None
    image_urls: list | None = None

# %%
def generateResponse():
  response = Company_Response()
  response.products_services = ['Furniture', 'Home decor', 'Kitchen and Dining']
  response.keywords = ['furniture', 'storage', 'lighting']
  response.classification = ['5712 (Furniture Stores) – SIC', '442110 (Furniture Stores) – NAICS']
  response.image_urls = ['https://serpapi.com/searches/6457b0f296f5d7b407953423/images/6b515bb71cfd9544e871f1a84db4ce91f0326052b4ce8cfa5a6e7b75aa833d50.png',
                         'https://serpapi.com/searches/6457b0f296f5d7b407953423/images/6b515bb71cfd95446106ea0179b25564db13ecd5dcd73f523c665affcf84c56c.jpeg',
                         'https://serpapi.com/searches/6457b0f296f5d7b407953423/images/6b515bb71cfd95444d5f3a3d16fab7d0d9b0d1ce65f296ea6f1a4a9547b12e11.jpeg']
  return response

# %%
app = FastAPI()

# %%
@app.post("/company/")
async def create_item(item: Company_Request):
  company_response = generateResponse()
  return company_response

# %%
ngrok_tunnel = ngrok.connect(8000)
print('Public URL:', ngrok_tunnel.public_url)
nest_asyncio.apply()
uvicorn.run(app, port=8000)
# Out:
# WARNING:pyngrok.process.ngrok:t=2023-05-11T07:15:26+0000 lvl=warn msg="ngrok config file found at legacy location, move to XDG location" xdg_path=/root/.config/ngrok/ngrok.yml legacy_path=/root/.ngrok2/ngrok.yml
# Public URL: https://bd0e-35-185-114-19.ngrok-free.app
# INFO:     Started server process [335]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# INFO:     103.77.3.151:0 - "GET / HTTP/1.1" 404 Not Found
# INFO:     103.77.3.151:0 - "GET /favicon.ico HTTP/1.1" 404 Not Found
# INFO:     103.77.3.151:0 - "GET /docs HTTP/1.1" 200 OK
# INFO:     103.77.3.151:0 - "GET /openapi.json HTTP/1.1" 200 OK
# INFO:     103.77.3.151:0 - "POST /items/ HTTP/1.1" 200 OK
# INFO:     Shutting down
# INFO:     Waiting for application shutdown.
# INFO:     Application shutdown complete.
# INFO:     Finished server process [335]

# %% [markdown]
# ---

# %% [markdown]
# **CACHE**

# %%
x = generateResponse()
x
# Out:
# Company_Response(products_services=['Furniture', 'Home decor', 'Kitchen and Dining'], keywords=['furniture', 'storage', 'lighting'], classification=['5712 (Furniture Stores) – SIC', '442110 (Furniture Stores) – NAICS'], image_urls=['https://serpapi.com/searches/6457b0f296f5d7b407953423/images/6b515bb71cfd9544e871f1a84db4ce91f0326052b4ce8cfa5a6e7b75aa833d50.png', 'https://serpapi.com/searches/6457b0f296f5d7b407953423/images/6b515bb71cfd95446106ea0179b25564db13ecd5dcd73f523c665affcf84c56c.jpeg', 'https://serpapi.com/searches/6457b0f296f5d7b407953423/images/6b515bb71cfd95444d5f3a3d16fab7d0d9b0d1ce65f296ea6f1a4a9547b12e11.jpeg'])

# %%
@app.get('/')
async def root():
    return {'hello': 'world'}
